# %% [markdown]
# # <center> Estructuras de Datos</center>
# ## <center> Universidad Nacional de Tres de Febrero</center>
# ## <center>Guía de ejercicios 9: Expresiones Regulares</center>

# %% [markdown]
# ### Ejercicio 1
# Indicar cuales de las siguientes cadenas son aceptadas por la expresión regular:
#
# `[a-z][\.\?!]\s+[A-Z]`
#
# - A. B
# -  c! d
# -  e f
# - g.   H
# - i?  J
#
# Justificar

# %% [markdown]
# ### Ejercicio 2
# Escribir expresiones regulares sobre números binarios que acepten los siguientes números:
#
#     1. terminados en 01
#     2. contienen una cantidad par de 0’s
#     3. cada 0 está seguido del al menos un 1

# %% [markdown]
# ### Ejercicio 3
# Escribir una expresión regular que acepte horas con el siguiente formato: HH:MM donde HH puede estar entre 00 y 23 y MM entre 00 y 59

# %% [markdown]
# ### Ejercicio 4
# Escribir una expresión regular que acepte un nodo XML.
#
# Debe aceptar:
# 1.
# ```xml
# <verso>Mi corazón oprimido</verso>
# ```
#
# 2.
# ```xml
# <autor fechaNacimiento="28/03/1936">Mario Vargas Llosa</autor>
# ```
# 3.
# ```xml
#  <libro>
#         <titulo>Conversación en la catedral</titulo>
#         <autor fechaNacimiento="28/03/1936">Mario Vargas Llosa</autor>
#         <precio>541.78</precio>
#     </libro>
# ```

# %% [markdown]
# ### Ejercicio 5
# Escribir una expresión regular que acepte solo identificadores en Camel Case. Por ejemplo:
#
# - unaFuncion
#
# - mergeSort

# %% [markdown]
# ### Ejercicio 6
# Escribir un programa en Python que valide una url ingresada por teclado por el usuario. Ver figura.
#
# Donde scheme puede ser: http, https, ftp o file
# Los subcomponentes userinfo, port, query y fragment son opcionales.
#
# El path consiste en una secuencia de segmentos de path validos, separados por una barra. También es opcional, es decir puede no estar.
#
# Las siguientes son URLs válidas
# 1. http://localhost/
# 2. http://127.0.0.1:80/
# 3. https://localhost:8888/lab
# 4. ftp://usuario:password@ftp.domain.ext/folder/
# 5. https://hb.redlink.com.ar/bna/home.htm#ultimosMovimientos

# %% [markdown]
# ![url.png](data:image/png;base64,...)

# %% [markdown]
# ### Ejercicio 7
# Escribir un programa para validar password que el usuario ingresa por teclado. Las password deben:
# - tener entre 6 y 10 caracteres \w
# - debe incluir al menos una letra mínuscula
# - debe incluir al menos una letra mayúscula
# - debe incluir al menos un dígito \d
#
# Pista: usar miradas alrededor
